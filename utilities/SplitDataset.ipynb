# %%
from ultralytics.data.utils import autosplit

autosplit(  
    path=r"./3dprint_full",
    weights=(0.8, 0.1, 0.1),  # (train, validation, test) fractional splits
    annotated_only=False,  # split only images with annotation file when True
)
# Out:
# Autosplitting images from 3dprint_full
# 100%|██████████| 820/820 [00:00<00:00, 14175.32it/s]

# %%
import os
import shutil

# Define the paths for the dataset and splits
base_path = r"./3dprint_full/"  # Base path to the images
split_files = {
    'train': 'autosplit_train.txt',  # Path to the train split file
    'val': 'autosplit_val.txt',      # Path to the validation split file
    'test': 'autosplit_test.txt'     # Path to the test split file
}
output_dirs = {
    'train': './train/',
    'val': './val/',
    'test': './test/'
}

# Create output directories if they don't exist
for split, output_dir in output_dirs.items():
    os.makedirs(output_dir, exist_ok=True)

# Function to move files and their labels based on split
def move_files_with_labels(split_name, split_file, output_dir):
    with open(split_file, 'r') as f:
        file_paths = [line.strip() for line in f.readlines()]
    
    for file_path in file_paths:
        image_full_path = os.path.join(base_path, os.path.basename(file_path))
        label_full_path = os.path.splitext(image_full_path)[0] + '.txt'  # Construct label file path
        
        # Move image file
        if os.path.exists(image_full_path):
            shutil.move(image_full_path, output_dir)
            print(f"Moved {image_full_path} to {output_dir}")
        else:
            print(f"Image file {image_full_path} does not exist and was skipped.")
        
        # Move corresponding label file
        if os.path.exists(label_full_path):
            shutil.move(label_full_path, output_dir)
            print(f"Moved {label_full_path} to {output_dir}")
        else:
            print(f"Label file {label_full_path} does not exist and was skipped.")

# Process each split
for split_name, split_file in split_files.items():
    move_files_with_labels(split_name, split_file, output_dirs[split_name])

print("Dataset files and labels have been moved to respective directories.")
# Out:
# Moved ./3dprint_full/BA002.png to ./train/
# Label file ./3dprint_full/BA002.txt does not exist and was skipped.
# Moved ./3dprint_full/BA003.png to ./train/
# Label file ./3dprint_full/BA003.txt does not exist and was skipped.
# Moved ./3dprint_full/BA004.png to ./train/
# Label file ./3dprint_full/BA004.txt does not exist and was skipped.
# Moved ./3dprint_full/BA005.png to ./train/
# Label file ./3dprint_full/BA005.txt does not exist and was skipped.
# Moved ./3dprint_full/BA006.png to ./train/
# Label file ./3dprint_full/BA006.txt does not exist and was skipped.
# Moved ./3dprint_full/BA007.png to ./train/
# Label file ./3dprint_full/BA007.txt does not exist and was skipped.
# Moved ./3dprint_full/BA008.png to ./train/
# Label file ./3dprint_full/BA008.txt does not exist and was skipped.
# Moved ./3dprint_full/BA009.png to ./train/
# Label file ./3dprint_full/BA009.txt does not exist and was skipped.
# Moved ./3dprint_full/BA010.png to ./train/
# Label file ./3dprint_full/BA010.txt does not exist and was skipped.
# Moved ./3dprint_full/BA012.png to ./train/
# Label file ./3dprint_full/BA012.txt does not exist and was skipped.
# Moved ./3dprint_full/BA013.png to ./train/
# Label file ./3dprint_full/BA013.txt does not exist and was skipped.
# Moved ./3dprint_full/BA014.png to ./train/
# Label file ./3dprint_full/BA014.txt does not exist and was skipped.
# Moved ./3dprint_full/BA015.png to ./train/
# Label file ./3dprint_full/BA015.txt does not exist and was skipped.
# Moved ./3dprint_full/BA016.png to ./train/
# Label file ./3dprint_full/BA016.txt does not exist and was skipped.
# Moved ./3dprint_full/BA021.png to ./train/
# Label file ./3dprint_full/BA021.txt does not exist and was skipped.
# Moved ./3dprint_full/BA022.png to ./train/
# Label file ./3dprint_full/BA022.txt does not exist and was skipped.
# Moved ./3dprint_full/BA024.png to ./train/
# Label file ./3dprint_full/BA024.txt does not exist and was skipped.
# Moved ./3dprint_full/BA025.png to ./train/
# Label file ./3dprint_full/BA025.txt does not exist and was skipped.
# Moved ./3dprint_full/BA026.png to ./train/
# Label file ./3dprint_full/BA026.txt does not exist and was skipped.
# Moved ./3dprint_full/BA027.png to ./train/
# Label file ./3dprint_full/BA027.txt does not exist and was skipped.
# Moved ./3dprint_full/BA028.png to ./train/
# Label file ./3dprint_full/BA028.txt does not exist and was skipped.
# Moved ./3dprint_full/BA031.png to ./train/
# Label file ./3dprint_full/BA031.txt does not exist and was skipped.
# Moved ./3dprint_full/BA033.png to ./train/
# Label file ./3dprint_full/BA033.txt does not exist and was skipped.
# Moved ./3dprint_full/BA035.png to ./train/
# Label file ./3dprint_full/BA035.txt does not exist and was skipped.
# Moved ./3dprint_full/BA036.png to ./train/
# Label file ./3dprint_full/BA036.txt does not exist and was skipped.
# Moved ./3dprint_full/BA037.png to ./train/
# Label file ./3dprint_full/BA037.txt does not exist and was skipped.
# Moved ./3dprint_full/BA038.png to ./train/
# Label file ./3dprint_full/BA038.txt does not exist and was skipped.
# Moved ./3dprint_full/BA040.png to ./train/
# Label file ./3dprint_full/BA040.txt does not exist and was skipped.
# Moved ./3dprint_full/BA041.png to ./train/
# Label file ./3dprint_full/BA041.txt does not exist and was skipped.
# Moved ./3dprint_full/BA042.png to ./train/
# Label file ./3dprint_full/BA042.txt does not exist and was skipped.
# Moved ./3dprint_full/BA044.png to ./train/
# Label file ./3dprint_full/BA044.txt does not exist and was skipped.
# Moved ./3dprint_full/BA045.png to ./train/
# Label file ./3dprint_full/BA045.txt does not exist and was skipped.
# Moved ./3dprint_full/BA047.png to ./train/
# Label file ./3dprint_full/BA047.txt does not exist and was skipped.
# Moved ./3dprint_full/BA048.png to ./train/
# Label file ./3dprint_full/BA048.txt does not exist and was skipped.
# Moved ./3dprint_full/BA049.png to ./train/
# Label file ./3dprint_full/BA049.txt does not exist and was skipped.
# Moved ./3dprint_full/BA052.png to ./train/
# Label file ./3dprint_full/BA052.txt does not exist and was skipped.
# Moved ./3dprint_full/BA053.png to ./train/
# Label file ./3dprint_full/BA053.txt does not exist and was skipped.
# Moved ./3dprint_full/BA054.png to ./train/
# Label file ./3dprint_full/BA054.txt does not exist and was skipped.
# Moved ./3dprint_full/BA055.png to ./train/
# Label file ./3dprint_full/BA055.txt does not exist and was skipped.
# Moved ./3dprint_full/BA057.png to ./train/
# Label file ./3dprint_full/BA057.txt does not exist and was skipped.
# Moved ./3dprint_full/BA058.png to ./train/
# Label file ./3dprint_full/BA058.txt does not exist and was skipped.
# Moved ./3dprint_full/BA059.png to ./train/
# Label file ./3dprint_full/BA059.txt does not exist and was skipped.
# Moved ./3dprint_full/BA060.png to ./train/
# Label file ./3dprint_full/BA060.txt does not exist and was skipped.
# Moved ./3dprint_full/BA062.png to ./train/
# Label file ./3dprint_full/BA062.txt does not exist and was skipped.
# Moved ./3dprint_full/BA064.png to ./train/
# Label file ./3dprint_full/BA064.txt does not exist and was skipped.
# Moved ./3dprint_full/BA065.png to ./train/
# Label file ./3dprint_full/BA065.txt does not exist and was skipped.
# Moved ./3dprint_full/BA066.png to ./train/
# Label file ./3dprint_full/BA066.txt does not exist and was skipped.
# Moved ./3dprint_full/BA067.png to ./train/
# Label file ./3dprint_full/BA067.txt does not exist and was skipped.
# Moved ./3dprint_full/BA068.png to ./train/
# Label file ./3dprint_full/BA068.txt does not exist and was skipped.
# Moved ./3dprint_full/BA069.png to ./train/
# Label file ./3dprint_full/BA069.txt does not exist and was skipped.
# Moved ./3dprint_full/BA070.png to ./train/
# Label file ./3dprint_full/BA070.txt does not exist and was skipped.
# Moved ./3dprint_full/BA071.png to ./train/
# Label file ./3dprint_full/BA071.txt does not exist and was skipped.
# Moved ./3dprint_full/BA072.png to ./train/
# Label file ./3dprint_full/BA072.txt does not exist and was skipped.
# Moved ./3dprint_full/BA073.png to ./train/
# Label file ./3dprint_full/BA073.txt does not exist and was skipped.
# Moved ./3dprint_full/BA074.png to ./train/
# Label file ./3dprint_full/BA074.txt does not exist and was skipped.
# Moved ./3dprint_full/BA075.png to ./train/
# Label file ./3dprint_full/BA075.txt does not exist and was skipped.
# Moved ./3dprint_full/BA076.png to ./train/
# Label file ./3dprint_full/BA076.txt does not exist and was skipped.
# Moved ./3dprint_full/BA077.png to ./train/
# Label file ./3dprint_full/BA077.txt does not exist and was skipped.
# Moved ./3dprint_full/BA083.png to ./train/
# Label file ./3dprint_full/BA083.txt does not exist and was skipped.
# Moved ./3dprint_full/BA084.png to ./train/
# Label file ./3dprint_full/BA084.txt does not exist and was skipped.
# Moved ./3dprint_full/BA085.png to ./train/
# Label file ./3dprint_full/BA085.txt does not exist and was skipped.
# Moved ./3dprint_full/BA086.png to ./train/
# Label file ./3dprint_full/BA086.txt does not exist and was skipped.
# Moved ./3dprint_full/BA090.png to ./train/
# Label file ./3dprint_full/BA090.txt does not exist and was skipped.
# Moved ./3dprint_full/BA092.png to ./train/
# Label file ./3dprint_full/BA092.txt does not exist and was skipped.
# Moved ./3dprint_full/BA093.png to ./train/
# Label file ./3dprint_full/BA093.txt does not exist and was skipped.
# Moved ./3dprint_full/BA094.png to ./train/
# Label file ./3dprint_full/BA094.txt does not exist and was skipped.
# Moved ./3dprint_full/BA097.png to ./train/
# Label file ./3dprint_full/BA097.txt does not exist and was skipped.
# Moved ./3dprint_full/BA098.png to ./train/
# Label file ./3dprint_full/BA098.txt does not exist and was skipped.
# Moved ./3dprint_full/BA099.png to ./train/
# Label file ./3dprint_full/BA099.txt does not exist and was skipped.
# Moved ./3dprint_full/BA100.png to ./train/
# Label file ./3dprint_full/BA100.txt does not exist and was skipped.
# Moved ./3dprint_full/BA101.png to ./train/
# Label file ./3dprint_full/BA101.txt does not exist and was skipped.
# Moved ./3dprint_full/BA103.png to ./train/
# Label file ./3dprint_full/BA103.txt does not exist and was skipped.
# Moved ./3dprint_full/BA104.png to ./train/
# Label file ./3dprint_full/BA104.txt does not exist and was skipped.
# Moved ./3dprint_full/BA105.png to ./train/
# Label file ./3dprint_full/BA105.txt does not exist and was skipped.
# Moved ./3dprint_full/BA106.png to ./train/
# Label file ./3dprint_full/BA106.txt does not exist and was skipped.
# Moved ./3dprint_full/BA107.png to ./train/
# Label file ./3dprint_full/BA107.txt does not exist and was skipped.
# Moved ./3dprint_full/BA108.png to ./train/
# Label file ./3dprint_full/BA108.txt does not exist and was skipped.
# Moved ./3dprint_full/BA110.png to ./train/
# Label file ./3dprint_full/BA110.txt does not exist and was skipped.
# Moved ./3dprint_full/BA111.png to ./train/
# Label file ./3dprint_full/BA111.txt does not exist and was skipped.
# Moved ./3dprint_full/BA112.png to ./train/
# Label file ./3dprint_full/BA112.txt does not exist and was skipped.
# Moved ./3dprint_full/BA113.png to ./train/
# Label file ./3dprint_full/BA113.txt does not exist and was skipped.
# Moved ./3dprint_full/BA114.png to ./train/
# Label file ./3dprint_full/BA114.txt does not exist and was skipped.
# Moved ./3dprint_full/BA116.png to ./train/
# Label file ./3dprint_full/BA116.txt does not exist and was skipped.
# Moved ./3dprint_full/BA117.png to ./train/
# Label file ./3dprint_full/BA117.txt does not exist and was skipped.
# Moved ./3dprint_full/BA118.png to ./train/
# Label file ./3dprint_full/BA118.txt does not exist and was skipped.
# Moved ./3dprint_full/BA119.png to ./train/
# Label file ./3dprint_full/BA119.txt does not exist and was skipped.
# Moved ./3dprint_full/BA120.png to ./train/
# Label file ./3dprint_full/BA120.txt does not exist and was skipped.
# Moved ./3dprint_full/BA121.png to ./train/
# Label file ./3dprint_full/BA121.txt does not exist and was skipped.
# Moved ./3dprint_full/BA122.png to ./train/
# Label file ./3dprint_full/BA122.txt does not exist and was skipped.
# Moved ./3dprint_full/BA123.png to ./train/
# Label file ./3dprint_full/BA123.txt does not exist and was skipped.
# Moved ./3dprint_full/BA125.png to ./train/
# Label file ./3dprint_full/BA125.txt does not exist and was skipped.
# Moved ./3dprint_full/BA126.png to ./train/
# Label file ./3dprint_full/BA126.txt does not exist and was skipped.
# Moved ./3dprint_full/BA128.png to ./train/
# Label file ./3dprint_full/BA128.txt does not exist and was skipped.
# Moved ./3dprint_full/BA129.png to ./train/
# Label file ./3dprint_full/BA129.txt does not exist and was skipped.
# Moved ./3dprint_full/BA130.png to ./train/
# Label file ./3dprint_full/BA130.txt does not exist and was skipped.
# Moved ./3dprint_full/BA133.png to ./train/
# Label file ./3dprint_full/BA133.txt does not exist and was skipped.
# Moved ./3dprint_full/BA134.png to ./train/
# Label file ./3dprint_full/BA134.txt does not exist and was skipped.
# Moved ./3dprint_full/BA135.png to ./train/
# Label file ./3dprint_full/BA135.txt does not exist and was skipped.
# Moved ./3dprint_full/BA136.png to ./train/
# Label file ./3dprint_full/BA136.txt does not exist and was skipped.
# Moved ./3dprint_full/BA137.png to ./train/
# Label file ./3dprint_full/BA137.txt does not exist and was skipped.
# Moved ./3dprint_full/BA138.png to ./train/
# Label file ./3dprint_full/BA138.txt does not exist and was skipped.
# Moved ./3dprint_full/BA139.png to ./train/
# Label file ./3dprint_full/BA139.txt does not exist and was skipped.
# Moved ./3dprint_full/BA140.png to ./train/
# Label file ./3dprint_full/BA140.txt does not exist and was skipped.
# Moved ./3dprint_full/BA141.png to ./train/
# Label file ./3dprint_full/BA141.txt does not exist and was skipped.
# Moved ./3dprint_full/BA142.png to ./train/
# Label file ./3dprint_full/BA142.txt does not exist and was skipped.
# Moved ./3dprint_full/BA143.png to ./train/
# Label file ./3dprint_full/BA143.txt does not exist and was skipped.
# Moved ./3dprint_full/BA145.png to ./train/
# Label file ./3dprint_full/BA145.txt does not exist and was skipped.
# Moved ./3dprint_full/BA146.png to ./train/
# Label file ./3dprint_full/BA146.txt does not exist and was skipped.
# Moved ./3dprint_full/BA147.png to ./train/
# Label file ./3dprint_full/BA147.txt does not exist and was skipped.
# Moved ./3dprint_full/BA150.png to ./train/
# Label file ./3dprint_full/BA150.txt does not exist and was skipped.
# Moved ./3dprint_full/BA151.png to ./train/
# Label file ./3dprint_full/BA151.txt does not exist and was skipped.
# Moved ./3dprint_full/BA153.png to ./train/
# Label file ./3dprint_full/BA153.txt does not exist and was skipped.
# Moved ./3dprint_full/BA154.png to ./train/
# Label file ./3dprint_full/BA154.txt does not exist and was skipped.
# Moved ./3dprint_full/BA156.png to ./train/
# Label file ./3dprint_full/BA156.txt does not exist and was skipped.
# Moved ./3dprint_full/BA157.png to ./train/
# Label file ./3dprint_full/BA157.txt does not exist and was skipped.
# Moved ./3dprint_full/BA158.png to ./train/
# Label file ./3dprint_full/BA158.txt does not exist and was skipped.
# Moved ./3dprint_full/BA159.png to ./train/
# Label file ./3dprint_full/BA159.txt does not exist and was skipped.
# Moved ./3dprint_full/BA160.png to ./train/
# Label file ./3dprint_full/BA160.txt does not exist and was skipped.
# Moved ./3dprint_full/BA161.png to ./train/
# Label file ./3dprint_full/BA161.txt does not exist and was skipped.
# Moved ./3dprint_full/BA162.png to ./train/
# Label file ./3dprint_full/BA162.txt does not exist and was skipped.
# Moved ./3dprint_full/BA163.png to ./train/
# Label file ./3dprint_full/BA163.txt does not exist and was skipped.
# Moved ./3dprint_full/BA164.png to ./train/
# Label file ./3dprint_full/BA164.txt does not exist and was skipped.
# Moved ./3dprint_full/BA165.png to ./train/
# Label file ./3dprint_full/BA165.txt does not exist and was skipped.
# Moved ./3dprint_full/BA166.png to ./train/
# Label file ./3dprint_full/BA166.txt does not exist and was skipped.
# Moved ./3dprint_full/BA168.png to ./train/
# Label file ./3dprint_full/BA168.txt does not exist and was skipped.
# Moved ./3dprint_full/BA169.png to ./train/
# Label file ./3dprint_full/BA169.txt does not exist and was skipped.
# Moved ./3dprint_full/BA170.png to ./train/
# Label file ./3dprint_full/BA170.txt does not exist and was skipped.
# Moved ./3dprint_full/BA171.png to ./train/
# Label file ./3dprint_full/BA171.txt does not exist and was skipped.
# Moved ./3dprint_full/BA172.png to ./train/
# Label file ./3dprint_full/BA172.txt does not exist and was skipped.
# Moved ./3dprint_full/BA173.png to ./train/
# Label file ./3dprint_full/BA173.txt does not exist and was skipped.
# Moved ./3dprint_full/BA174.png to ./train/
# Label file ./3dprint_full/BA174.txt does not exist and was skipped.
# Moved ./3dprint_full/BA175.png to ./train/
# Label file ./3dprint_full/BA175.txt does not exist and was skipped.
# Moved ./3dprint_full/BA177.png to ./train/
# Label file ./3dprint_full/BA177.txt does not exist and was skipped.
# Moved ./3dprint_full/BA178.png to ./train/
# Label file ./3dprint_full/BA178.txt does not exist and was skipped.
# Moved ./3dprint_full/BG01.jpg to ./train/
# Label file ./3dprint_full/BG01.txt does not exist and was skipped.
# Moved ./3dprint_full/BG03.jpg to ./train/
# Label file ./3dprint_full/BG03.txt does not exist and was skipped.
# Moved ./3dprint_full/BG04.jpg to ./train/
# Label file ./3dprint_full/BG04.txt does not exist and was skipped.
# Moved ./3dprint_full/BG05.jpg to ./train/
# Label file ./3dprint_full/BG05.txt does not exist and was skipped.
# Moved ./3dprint_full/BG06.jpg to ./train/
# Label file ./3dprint_full/BG06.txt does not exist and was skipped.
# Moved ./3dprint_full/BG07.jpg to ./train/
# Label file ./3dprint_full/BG07.txt does not exist and was skipped.
# Moved ./3dprint_full/BG08.jpg to ./train/
# Label file ./3dprint_full/BG08.txt does not exist and was skipped.
# Moved ./3dprint_full/BG09.jpg to ./train/
# Label file ./3dprint_full/BG09.txt does not exist and was skipped.
# Moved ./3dprint_full/BG10.jpg to ./train/
# Label file ./3dprint_full/BG10.txt does not exist and was skipped.
# Moved ./3dprint_full/BG100.jpg to ./train/
# Label file ./3dprint_full/BG100.txt does not exist and was skipped.
# Moved ./3dprint_full/BG101.jpg to ./train/
# Label file ./3dprint_full/BG101.txt does not exist and was skipped.
# Moved ./3dprint_full/BG102.jpg to ./train/
# Label file ./3dprint_full/BG102.txt does not exist and was skipped.
# Moved ./3dprint_full/BG103.jpg to ./train/
# Label file ./3dprint_full/BG103.txt does not exist and was skipped.
# Moved ./3dprint_full/BG105.jpg to ./train/
# Label file ./3dprint_full/BG105.txt does not exist and was skipped.
# Moved ./3dprint_full/BG106.jpg to ./train/
# Label file ./3dprint_full/BG106.txt does not exist and was skipped.
# Moved ./3dprint_full/BG107.jpg to ./train/
# Label file ./3dprint_full/BG107.txt does not exist and was skipped.
# Moved ./3dprint_full/BG108.jpg to ./train/
# Label file ./3dprint_full/BG108.txt does not exist and was skipped.
# Moved ./3dprint_full/BG109.jpg to ./train/
# Label file ./3dprint_full/BG109.txt does not exist and was skipped.
# Moved ./3dprint_full/BG11.jpg to ./train/
# Label file ./3dprint_full/BG11.txt does not exist and was skipped.
# Moved ./3dprint_full/BG110.jpg to ./train/
# Label file ./3dprint_full/BG110.txt does not exist and was skipped.
# Moved ./3dprint_full/BG111.jpg to ./train/
# Label file ./3dprint_full/BG111.txt does not exist and was skipped.
# Moved ./3dprint_full/BG112.jpg to ./train/
# Label file ./3dprint_full/BG112.txt does not exist and was skipped.
# Moved ./3dprint_full/BG113.jpg to ./train/
# Label file ./3dprint_full/BG113.txt does not exist and was skipped.
# Moved ./3dprint_full/BG114.jpg to ./train/
# Label file ./3dprint_full/BG114.txt does not exist and was skipped.
# Moved ./3dprint_full/BG115.jpg to ./train/
# Label file ./3dprint_full/BG115.txt does not exist and was skipped.
# Moved ./3dprint_full/BG116.jpg to ./train/
# Label file ./3dprint_full/BG116.txt does not exist and was skipped.
# Moved ./3dprint_full/BG117.jpg to ./train/
# Label file ./3dprint_full/BG117.txt does not exist and was skipped.
# Moved ./3dprint_full/BG119.jpg to ./train/
# Label file ./3dprint_full/BG119.txt does not exist and was skipped.
# Moved ./3dprint_full/BG12.jpg to ./train/
# Label file ./3dprint_full/BG12.txt does not exist and was skipped.
# Moved ./3dprint_full/BG120.jpg to ./train/
# Label file ./3dprint_full/BG120.txt does not exist and was skipped.
# Moved ./3dprint_full/BG124.jpg to ./train/
# Label file ./3dprint_full/BG124.txt does not exist and was skipped.
# Moved ./3dprint_full/BG126.jpg to ./train/
# Label file ./3dprint_full/BG126.txt does not exist and was skipped.
# Moved ./3dprint_full/BG127.jpg to ./train/
# Label file ./3dprint_full/BG127.txt does not exist and was skipped.
# Moved ./3dprint_full/BG128.jpg to ./train/
# Label file ./3dprint_full/BG128.txt does not exist and was skipped.
# Moved ./3dprint_full/BG13.jpg to ./train/
# Label file ./3dprint_full/BG13.txt does not exist and was skipped.
# Moved ./3dprint_full/BG130.jpg to ./train/
# Label file ./3dprint_full/BG130.txt does not exist and was skipped.
# Moved ./3dprint_full/BG131.jpg to ./train/
# Label file ./3dprint_full/BG131.txt does not exist and was skipped.
# Moved ./3dprint_full/BG132.jpg to ./train/
# Label file ./3dprint_full/BG132.txt does not exist and was skipped.
# Moved ./3dprint_full/BG133.jpg to ./train/
# Label file ./3dprint_full/BG133.txt does not exist and was skipped.
# Moved ./3dprint_full/BG134.jpg to ./train/
# Label file ./3dprint_full/BG134.txt does not exist and was skipped.
# Moved ./3dprint_full/BG136.jpg to ./train/
# Label file ./3dprint_full/BG136.txt does not exist and was skipped.
# Moved ./3dprint_full/BG137.jpg to ./train/
# Label file ./3dprint_full/BG137.txt does not exist and was skipped.
# Moved ./3dprint_full/BG138.jpg to ./train/
# Label file ./3dprint_full/BG138.txt does not exist and was skipped.
# Moved ./3dprint_full/BG14.jpg to ./train/
# Label file ./3dprint_full/BG14.txt does not exist and was skipped.
# Moved ./3dprint_full/BG16.jpg to ./train/
# Label file ./3dprint_full/BG16.txt does not exist and was skipped.
# Moved ./3dprint_full/BG18.jpg to ./train/
# Label file ./3dprint_full/BG18.txt does not exist and was skipped.
# Moved ./3dprint_full/BG20.jpg to ./train/
# Label file ./3dprint_full/BG20.txt does not exist and was skipped.
# Moved ./3dprint_full/BG21.jpg to ./train/
# Label file ./3dprint_full/BG21.txt does not exist and was skipped.
# Moved ./3dprint_full/BG22.jpg to ./train/
# Label file ./3dprint_full/BG22.txt does not exist and was skipped.
# Moved ./3dprint_full/BG23.jpg to ./train/
# Label file ./3dprint_full/BG23.txt does not exist and was skipped.
# Moved ./3dprint_full/BG24.jpg to ./train/
# Label file ./3dprint_full/BG24.txt does not exist and was skipped.
# Moved ./3dprint_full/BG26.jpg to ./train/
# Label file ./3dprint_full/BG26.txt does not exist and was skipped.
# Moved ./3dprint_full/BG27.jpg to ./train/
# Label file ./3dprint_full/BG27.txt does not exist and was skipped.
# Moved ./3dprint_full/BG28.jpg to ./train/
# Label file ./3dprint_full/BG28.txt does not exist and was skipped.
# Moved ./3dprint_full/BG29.jpg to ./train/
# Label file ./3dprint_full/BG29.txt does not exist and was skipped.
# Moved ./3dprint_full/BG31.jpg to ./train/
# Label file ./3dprint_full/BG31.txt does not exist and was skipped.
# Moved ./3dprint_full/BG32.jpg to ./train/
# Label file ./3dprint_full/BG32.txt does not exist and was skipped.
# Moved ./3dprint_full/BG33.jpg to ./train/
# Label file ./3dprint_full/BG33.txt does not exist and was skipped.
# Moved ./3dprint_full/BG34.jpg to ./train/
# Label file ./3dprint_full/BG34.txt does not exist and was skipped.
# Moved ./3dprint_full/BG35.jpg to ./train/
# Label file ./3dprint_full/BG35.txt does not exist and was skipped.
# Moved ./3dprint_full/BG39.jpg to ./train/
# Label file ./3dprint_full/BG39.txt does not exist and was skipped.
# Moved ./3dprint_full/BG40.jpg to ./train/
# Label file ./3dprint_full/BG40.txt does not exist and was skipped.
# Moved ./3dprint_full/BG41.jpg to ./train/
# Label file ./3dprint_full/BG41.txt does not exist and was skipped.
# Moved ./3dprint_full/BG42.jpg to ./train/
# Label file ./3dprint_full/BG42.txt does not exist and was skipped.
# Moved ./3dprint_full/BG43.jpg to ./train/
# Label file ./3dprint_full/BG43.txt does not exist and was skipped.
# Moved ./3dprint_full/BG45.jpg to ./train/
# Label file ./3dprint_full/BG45.txt does not exist and was skipped.
# Moved ./3dprint_full/BG46.jpg to ./train/
# Label file ./3dprint_full/BG46.txt does not exist and was skipped.
# Moved ./3dprint_full/BG47.jpg to ./train/
# Label file ./3dprint_full/BG47.txt does not exist and was skipped.
# Moved ./3dprint_full/BG48.jpg to ./train/
# Label file ./3dprint_full/BG48.txt does not exist and was skipped.
# Moved ./3dprint_full/BG49.jpg to ./train/
# Label file ./3dprint_full/BG49.txt does not exist and was skipped.
# Moved ./3dprint_full/BG50.jpg to ./train/
# Label file ./3dprint_full/BG50.txt does not exist and was skipped.
# Moved ./3dprint_full/BG51.jpg to ./train/
# Label file ./3dprint_full/BG51.txt does not exist and was skipped.
# Moved ./3dprint_full/BG52.jpg to ./train/
# Label file ./3dprint_full/BG52.txt does not exist and was skipped.
# Moved ./3dprint_full/BG53.jpg to ./train/
# Label file ./3dprint_full/BG53.txt does not exist and was skipped.
# Moved ./3dprint_full/BG54.jpg to ./train/
# Label file ./3dprint_full/BG54.txt does not exist and was skipped.
# Moved ./3dprint_full/BG55.jpg to ./train/
# Label file ./3dprint_full/BG55.txt does not exist and was skipped.
# Moved ./3dprint_full/BG56.jpg to ./train/
# Label file ./3dprint_full/BG56.txt does not exist and was skipped.
# Moved ./3dprint_full/BG57.jpg to ./train/
# Label file ./3dprint_full/BG57.txt does not exist and was skipped.
# Moved ./3dprint_full/BG58.jpg to ./train/
# Label file ./3dprint_full/BG58.txt does not exist and was skipped.
# Moved ./3dprint_full/BG60.jpg to ./train/
# Label file ./3dprint_full/BG60.txt does not exist and was skipped.
# Moved ./3dprint_full/BG61.jpg to ./train/
# Label file ./3dprint_full/BG61.txt does not exist and was skipped.
# Moved ./3dprint_full/BG62.jpg to ./train/
# Label file ./3dprint_full/BG62.txt does not exist and was skipped.
# Moved ./3dprint_full/BG63.jpg to ./train/
# Label file ./3dprint_full/BG63.txt does not exist and was skipped.
# Moved ./3dprint_full/BG64.jpg to ./train/
# Label file ./3dprint_full/BG64.txt does not exist and was skipped.
# Moved ./3dprint_full/BG65.jpg to ./train/
# Label file ./3dprint_full/BG65.txt does not exist and was skipped.
# Moved ./3dprint_full/BG66.jpg to ./train/
# Label file ./3dprint_full/BG66.txt does not exist and was skipped.
# Moved ./3dprint_full/BG67.jpg to ./train/
# Label file ./3dprint_full/BG67.txt does not exist and was skipped.
# Moved ./3dprint_full/BG68.jpg to ./train/
# Label file ./3dprint_full/BG68.txt does not exist and was skipped.
# Moved ./3dprint_full/BG69.jpg to ./train/
# Label file ./3dprint_full/BG69.txt does not exist and was skipped.
# Moved ./3dprint_full/BG70.jpg to ./train/
# Label file ./3dprint_full/BG70.txt does not exist and was skipped.
# Moved ./3dprint_full/BG71.jpg to ./train/
# Label file ./3dprint_full/BG71.txt does not exist and was skipped.
# Moved ./3dprint_full/BG72.jpg to ./train/
# Label file ./3dprint_full/BG72.txt does not exist and was skipped.
# Moved ./3dprint_full/BG73.jpg to ./train/
# Label file ./3dprint_full/BG73.txt does not exist and was skipped.
# Moved ./3dprint_full/BG75.jpg to ./train/
# Label file ./3dprint_full/BG75.txt does not exist and was skipped.
# Moved ./3dprint_full/BG78.jpg to ./train/
# Label file ./3dprint_full/BG78.txt does not exist and was skipped.
# Moved ./3dprint_full/BG79.jpg to ./train/
# Label file ./3dprint_full/BG79.txt does not exist and was skipped.
# Moved ./3dprint_full/BG80.jpg to ./train/
# Label file ./3dprint_full/BG80.txt does not exist and was skipped.
# Moved ./3dprint_full/BG81.jpg to ./train/
# Label file ./3dprint_full/BG81.txt does not exist and was skipped.
# Moved ./3dprint_full/BG82.jpg to ./train/
# Label file ./3dprint_full/BG82.txt does not exist and was skipped.
# Moved ./3dprint_full/BG83.jpg to ./train/
# Label file ./3dprint_full/BG83.txt does not exist and was skipped.
# Moved ./3dprint_full/BG86.jpg to ./train/
# Label file ./3dprint_full/BG86.txt does not exist and was skipped.
# Moved ./3dprint_full/BG87.jpg to ./train/
# Label file ./3dprint_full/BG87.txt does not exist and was skipped.
# Moved ./3dprint_full/BG89.jpg to ./train/
# Label file ./3dprint_full/BG89.txt does not exist and was skipped.
# Moved ./3dprint_full/BG90.jpg to ./train/
# Label file ./3dprint_full/BG90.txt does not exist and was skipped.
# Moved ./3dprint_full/BG91.jpg to ./train/
# Label file ./3dprint_full/BG91.txt does not exist and was skipped.
# Moved ./3dprint_full/BG92.jpg to ./train/
# Label file ./3dprint_full/BG92.txt does not exist and was skipped.
# Moved ./3dprint_full/BG93.jpg to ./train/
# Label file ./3dprint_full/BG93.txt does not exist and was skipped.
# Moved ./3dprint_full/BG94.jpg to ./train/
# Label file ./3dprint_full/BG94.txt does not exist and was skipped.
# Moved ./3dprint_full/BG95.jpg to ./train/
# Label file ./3dprint_full/BG95.txt does not exist and was skipped.
# Moved ./3dprint_full/BG96.jpg to ./train/
# Label file ./3dprint_full/BG96.txt does not exist and was skipped.
# Moved ./3dprint_full/BG97.jpg to ./train/
# Label file ./3dprint_full/BG97.txt does not exist and was skipped.
# Moved ./3dprint_full/BG98.jpg to ./train/
# Label file ./3dprint_full/BG98.txt does not exist and was skipped.
# Moved ./3dprint_full/BG99.jpg to ./train/
# Label file ./3dprint_full/BG99.txt does not exist and was skipped.
# Moved ./3dprint_full/DP001.png to ./train/
# Moved ./3dprint_full/DP001.txt to ./train/
# Moved ./3dprint_full/DP002.png to ./train/
# Moved ./3dprint_full/DP002.txt to ./train/
# Moved ./3dprint_full/DP003.png to ./train/
# Moved ./3dprint_full/DP003.txt to ./train/
# Moved ./3dprint_full/DP005.png to ./train/
# Moved ./3dprint_full/DP005.txt to ./train/
# Moved ./3dprint_full/DP006.png to ./train/
# Moved ./3dprint_full/DP006.txt to ./train/
# Moved ./3dprint_full/DP007.png to ./train/
# Moved ./3dprint_full/DP007.txt to ./train/
# Moved ./3dprint_full/DP008.png to ./train/
# Moved ./3dprint_full/DP008.txt to ./train/
# Moved ./3dprint_full/DP009.png to ./train/
# Moved ./3dprint_full/DP009.txt to ./train/
# Moved ./3dprint_full/DP011.png to ./train/
# Moved ./3dprint_full/DP011.txt to ./train/
# Moved ./3dprint_full/DP013.png to ./train/
# Moved ./3dprint_full/DP013.txt to ./train/
# Moved ./3dprint_full/DP014.png to ./train/
# Moved ./3dprint_full/DP014.txt to ./train/
# Moved ./3dprint_full/DP015.png to ./train/
# Moved ./3dprint_full/DP015.txt to ./train/
# Moved ./3dprint_full/DP016.png to ./train/
# Moved ./3dprint_full/DP016.txt to ./train/
# Moved ./3dprint_full/DP017.png to ./train/
# Moved ./3dprint_full/DP017.txt to ./train/
# Moved ./3dprint_full/DP018.png to ./train/
# Moved ./3dprint_full/DP018.txt to ./train/
# Moved ./3dprint_full/DP020.png to ./train/
# Moved ./3dprint_full/DP020.txt to ./train/
# Moved ./3dprint_full/DP021.png to ./train/
# Moved ./3dprint_full/DP021.txt to ./train/
# Moved ./3dprint_full/DP022.png to ./train/
# Moved ./3dprint_full/DP022.txt to ./train/
# Moved ./3dprint_full/DP023.png to ./train/
# Moved ./3dprint_full/DP023.txt to ./train/
# Moved ./3dprint_full/DP024.png to ./train/
# Moved ./3dprint_full/DP024.txt to ./train/
# Moved ./3dprint_full/DP025.png to ./train/
# Moved ./3dprint_full/DP025.txt to ./train/
# Moved ./3dprint_full/DP028.png to ./train/
# Moved ./3dprint_full/DP028.txt to ./train/
# Moved ./3dprint_full/DP029.png to ./train/
# Moved ./3dprint_full/DP029.txt to ./train/
# Moved ./3dprint_full/DP030.png to ./train/
# Moved ./3dprint_full/DP030.txt to ./train/
# Moved ./3dprint_full/DP032.png to ./train/
# Moved ./3dprint_full/DP032.txt to ./train/
# Moved ./3dprint_full/DP034.png to ./train/
# Moved ./3dprint_full/DP034.txt to ./train/
# Moved ./3dprint_full/DP035.png to ./train/
# Moved ./3dprint_full/DP035.txt to ./train/
# Moved ./3dprint_full/DP036.png to ./train/
# Moved ./3dprint_full/DP036.txt to ./train/
# Moved ./3dprint_full/DP037.png to ./train/
# Moved ./3dprint_full/DP037.txt to ./train/
# Moved ./3dprint_full/DP038.png to ./train/
# Moved ./3dprint_full/DP038.txt to ./train/
# Moved ./3dprint_full/DP039.png to ./train/
# Moved ./3dprint_full/DP039.txt to ./train/
# Moved ./3dprint_full/DP040.png to ./train/
# Moved ./3dprint_full/DP040.txt to ./train/
# Moved ./3dprint_full/DP041.png to ./train/
# Moved ./3dprint_full/DP041.txt to ./train/
# Moved ./3dprint_full/DP045.png to ./train/
# Moved ./3dprint_full/DP045.txt to ./train/
# Moved ./3dprint_full/DP046.png to ./train/
# Moved ./3dprint_full/DP046.txt to ./train/
# Moved ./3dprint_full/DP047.png to ./train/
# Moved ./3dprint_full/DP047.txt to ./train/
# Moved ./3dprint_full/DP048.png to ./train/
# Moved ./3dprint_full/DP048.txt to ./train/
# Moved ./3dprint_full/DP051.png to ./train/
# Moved ./3dprint_full/DP051.txt to ./train/
# Moved ./3dprint_full/DP052.png to ./train/
# Moved ./3dprint_full/DP052.txt to ./train/
# Moved ./3dprint_full/DP054.png to ./train/
# Moved ./3dprint_full/DP054.txt to ./train/
# Moved ./3dprint_full/DP055.png to ./train/
# Moved ./3dprint_full/DP055.txt to ./train/
# Moved ./3dprint_full/DP057.png to ./train/
# Moved ./3dprint_full/DP057.txt to ./train/
# Moved ./3dprint_full/DP058.png to ./train/
# Moved ./3dprint_full/DP058.txt to ./train/
# Moved ./3dprint_full/DP059.png to ./train/
# Moved ./3dprint_full/DP059.txt to ./train/
# Moved ./3dprint_full/DP060.png to ./train/
# Moved ./3dprint_full/DP060.txt to ./train/
# Moved ./3dprint_full/DP062.png to ./train/
# Moved ./3dprint_full/DP062.txt to ./train/
# Moved ./3dprint_full/DP063.png to ./train/
# Moved ./3dprint_full/DP063.txt to ./train/
# Moved ./3dprint_full/DP064.png to ./train/
# Moved ./3dprint_full/DP064.txt to ./train/
# Moved ./3dprint_full/DP065.png to ./train/
# Moved ./3dprint_full/DP065.txt to ./train/
# Moved ./3dprint_full/DP067.png to ./train/
# Moved ./3dprint_full/DP067.txt to ./train/
# Moved ./3dprint_full/DP069.png to ./train/
# Moved ./3dprint_full/DP069.txt to ./train/
# Moved ./3dprint_full/DP070.png to ./train/
# Moved ./3dprint_full/DP070.txt to ./train/
# Moved ./3dprint_full/DP071.png to ./train/
# Moved ./3dprint_full/DP071.txt to ./train/
# Moved ./3dprint_full/DP073.png to ./train/
# Moved ./3dprint_full/DP073.txt to ./train/
# Moved ./3dprint_full/DP075.png to ./train/
# Moved ./3dprint_full/DP075.txt to ./train/
# Moved ./3dprint_full/DP078.png to ./train/
# Moved ./3dprint_full/DP078.txt to ./train/
# Moved ./3dprint_full/DP079.png to ./train/
# Moved ./3dprint_full/DP079.txt to ./train/
# Moved ./3dprint_full/DP081.png to ./train/
# Moved ./3dprint_full/DP081.txt to ./train/
# Moved ./3dprint_full/FA09.jpg to ./train/
# Moved ./3dprint_full/FA09.txt to ./train/
# Moved ./3dprint_full/FA10.jpg to ./train/
# Moved ./3dprint_full/FA10.txt to ./train/
# Moved ./3dprint_full/FA11.jpg to ./train/
# Moved ./3dprint_full/FA11.txt to ./train/
# Moved ./3dprint_full/FA12.jpg to ./train/
# Moved ./3dprint_full/FA12.txt to ./train/
# Moved ./3dprint_full/FA14.jpg to ./train/
# Moved ./3dprint_full/FA14.txt to ./train/
# Moved ./3dprint_full/FA15.jpg to ./train/
# Moved ./3dprint_full/FA15.txt to ./train/
# Moved ./3dprint_full/FA16.jpg to ./train/
# Moved ./3dprint_full/FA16.txt to ./train/
# Moved ./3dprint_full/FA17.jpg to ./train/
# Moved ./3dprint_full/FA17.txt to ./train/
# Moved ./3dprint_full/FA18.jpg to ./train/
# Moved ./3dprint_full/FA18.txt to ./train/
# Moved ./3dprint_full/FA19.jpg to ./train/
# Moved ./3dprint_full/FA19.txt to ./train/
# Moved ./3dprint_full/FA20.jpg to ./train/
# Moved ./3dprint_full/FA20.txt to ./train/
# Moved ./3dprint_full/FA23.jpg to ./train/
# Moved ./3dprint_full/FA23.txt to ./train/
# Moved ./3dprint_full/FA24.jpg to ./train/
# Moved ./3dprint_full/FA24.txt to ./train/
# Moved ./3dprint_full/FA26.jpg to ./train/
# Moved ./3dprint_full/FA26.txt to ./train/
# Moved ./3dprint_full/FA27.jpg to ./train/
# Moved ./3dprint_full/FA27.txt to ./train/
# Moved ./3dprint_full/FA28.jpg to ./train/
# Moved ./3dprint_full/FA28.txt to ./train/
# Moved ./3dprint_full/FA29.jpg to ./train/
# Moved ./3dprint_full/FA29.txt to ./train/
# Moved ./3dprint_full/FA31.jpg to ./train/
# Moved ./3dprint_full/FA31.txt to ./train/
# Moved ./3dprint_full/FB10.jpg to ./train/
# Moved ./3dprint_full/FB10.txt to ./train/
# Moved ./3dprint_full/FB11.jpg to ./train/
# Moved ./3dprint_full/FB11.txt to ./train/
# Moved ./3dprint_full/FB12.jpg to ./train/
# Moved ./3dprint_full/FB12.txt to ./train/
# Moved ./3dprint_full/FB14.jpg to ./train/
# Moved ./3dprint_full/FB14.txt to ./train/
# Moved ./3dprint_full/FB15.jpg to ./train/
# Moved ./3dprint_full/FB15.txt to ./train/
# Moved ./3dprint_full/FB16.jpg to ./train/
# Moved ./3dprint_full/FB16.txt to ./train/
# Moved ./3dprint_full/FB18.jpg to ./train/
# Moved ./3dprint_full/FB18.txt to ./train/
# Moved ./3dprint_full/FB19.jpg to ./train/
# Moved ./3dprint_full/FB19.txt to ./train/
# Moved ./3dprint_full/FB20.jpg to ./train/
# Moved ./3dprint_full/FB20.txt to ./train/
# Moved ./3dprint_full/FB21.jpg to ./train/
# Moved ./3dprint_full/FB21.txt to ./train/
# Moved ./3dprint_full/FB22.jpg to ./train/
# Moved ./3dprint_full/FB22.txt to ./train/
# Moved ./3dprint_full/FB23.jpg to ./train/
# Moved ./3dprint_full/FB23.txt to ./train/
# Moved ./3dprint_full/FB24.jpg to ./train/
# Moved ./3dprint_full/FB24.txt to ./train/
# Moved ./3dprint_full/FB25.jpg to ./train/
# Moved ./3dprint_full/FB25.txt to ./train/
# Moved ./3dprint_full/FB26.jpg to ./train/
# Moved ./3dprint_full/FB26.txt to ./train/
# Moved ./3dprint_full/FB27.jpg to ./train/
# Moved ./3dprint_full/FB27.txt to ./train/
# Moved ./3dprint_full/FB28.jpg to ./train/
# Moved ./3dprint_full/FB28.txt to ./train/
# Moved ./3dprint_full/FB29.jpg to ./train/
# Moved ./3dprint_full/FB29.txt to ./train/
# Moved ./3dprint_full/FB30.jpg to ./train/
# Moved ./3dprint_full/FB30.txt to ./train/
# Moved ./3dprint_full/FB31.jpg to ./train/
# Moved ./3dprint_full/FB31.txt to ./train/
# Moved ./3dprint_full/FC02.jpg to ./train/
# Moved ./3dprint_full/FC02.txt to ./train/
# Moved ./3dprint_full/FC04.jpg to ./train/
# Moved ./3dprint_full/FC04.txt to ./train/
# Moved ./3dprint_full/FC05.jpg to ./train/
# Moved ./3dprint_full/FC05.txt to ./train/
# Moved ./3dprint_full/FC06.jpg to ./train/
# Moved ./3dprint_full/FC06.txt to ./train/
# Moved ./3dprint_full/FC07.jpg to ./train/
# Moved ./3dprint_full/FC07.txt to ./train/
# Moved ./3dprint_full/FC08.jpg to ./train/
# Moved ./3dprint_full/FC08.txt to ./train/
# Moved ./3dprint_full/FC09.jpg to ./train/
# Moved ./3dprint_full/FC09.txt to ./train/
# Moved ./3dprint_full/FC10.jpg to ./train/
# Moved ./3dprint_full/FC10.txt to ./train/
# Moved ./3dprint_full/FC11.jpg to ./train/
# Moved ./3dprint_full/FC11.txt to ./train/
# Moved ./3dprint_full/FC12.jpg to ./train/
# Moved ./3dprint_full/FC12.txt to ./train/
# Moved ./3dprint_full/FC14.jpg to ./train/
# Moved ./3dprint_full/FC14.txt to ./train/
# Moved ./3dprint_full/FC17.jpg to ./train/
# Moved ./3dprint_full/FC17.txt to ./train/
# Moved ./3dprint_full/FC19.jpg to ./train/
# Moved ./3dprint_full/FC19.txt to ./train/
# Moved ./3dprint_full/FC20.jpg to ./train/
# Moved ./3dprint_full/FC20.txt to ./train/
# Moved ./3dprint_full/FC21.jpg to ./train/
# Moved ./3dprint_full/FC21.txt to ./train/
# Moved ./3dprint_full/FC22.jpg to ./train/
# Moved ./3dprint_full/FC22.txt to ./train/
# Moved ./3dprint_full/FC23.jpg to ./train/
# Moved ./3dprint_full/FC23.txt to ./train/
# Moved ./3dprint_full/FC24.jpg to ./train/
# Moved ./3dprint_full/FC24.txt to ./train/
# Moved ./3dprint_full/FC25.jpg to ./train/
# Moved ./3dprint_full/FC25.txt to ./train/
# Moved ./3dprint_full/FC26.jpg to ./train/
# Moved ./3dprint_full/FC26.txt to ./train/
# Moved ./3dprint_full/FC27.jpg to ./train/
# Moved ./3dprint_full/FC27.txt to ./train/
# Moved ./3dprint_full/FC28.jpg to ./train/
# Moved ./3dprint_full/FC28.txt to ./train/
# Moved ./3dprint_full/FC30.jpg to ./train/
# Moved ./3dprint_full/FC30.txt to ./train/
# Moved ./3dprint_full/FC33.jpg to ./train/
# Moved ./3dprint_full/FC33.txt to ./train/
# Moved ./3dprint_full/FC34.jpg to ./train/
# Moved ./3dprint_full/FC34.txt to ./train/
# Moved ./3dprint_full/FC35.jpg to ./train/
# Moved ./3dprint_full/FC35.txt to ./train/
# Moved ./3dprint_full/FC36.jpg to ./train/
# Moved ./3dprint_full/FC36.txt to ./train/
# Moved ./3dprint_full/FC39.jpg to ./train/
# Moved ./3dprint_full/FC39.txt to ./train/
# Moved ./3dprint_full/FC40.jpg to ./train/
# Moved ./3dprint_full/FC40.txt to ./train/
# Moved ./3dprint_full/FC41.jpg to ./train/
# Moved ./3dprint_full/FC41.txt to ./train/
# Moved ./3dprint_full/FC42.jpg to ./train/
# Moved ./3dprint_full/FC42.txt to ./train/
# Moved ./3dprint_full/FC43.jpg to ./train/
# Moved ./3dprint_full/FC43.txt to ./train/
# Moved ./3dprint_full/FC44.jpg to ./train/
# Moved ./3dprint_full/FC44.txt to ./train/
# Moved ./3dprint_full/FC45.jpg to ./train/
# Moved ./3dprint_full/FC45.txt to ./train/
# Moved ./3dprint_full/FC48.jpg to ./train/
# Moved ./3dprint_full/FC48.txt to ./train/
# Moved ./3dprint_full/FC49.jpg to ./train/
# Moved ./3dprint_full/FC49.txt to ./train/
# Moved ./3dprint_full/FC50.jpg to ./train/
# Moved ./3dprint_full/FC50.txt to ./train/
# Moved ./3dprint_full/FC51.jpg to ./train/
# Moved ./3dprint_full/FC51.txt to ./train/
# Moved ./3dprint_full/FC52.jpg to ./train/
# Moved ./3dprint_full/FC52.txt to ./train/
# Moved ./3dprint_full/FC53.jpg to ./train/
# Moved ./3dprint_full/FC53.txt to ./train/
# Moved ./3dprint_full/FC54.jpg to ./train/
# Moved ./3dprint_full/FC54.txt to ./train/
# Moved ./3dprint_full/FC55.jpg to ./train/
# Moved ./3dprint_full/FC55.txt to ./train/
# Moved ./3dprint_full/FC58.jpg to ./train/
# Moved ./3dprint_full/FC58.txt to ./train/
# Moved ./3dprint_full/FC59.jpg to ./train/
# Moved ./3dprint_full/FC59.txt to ./train/
# Moved ./3dprint_full/FC60.jpg to ./train/
# Moved ./3dprint_full/FC60.txt to ./train/
# Moved ./3dprint_full/FC61.jpg to ./train/
# Moved ./3dprint_full/FC61.txt to ./train/
# Moved ./3dprint_full/FC62.jpg to ./train/
# Moved ./3dprint_full/FC62.txt to ./train/
# Moved ./3dprint_full/FC63.jpg to ./train/
# Moved ./3dprint_full/FC63.txt to ./train/
# Moved ./3dprint_full/FC64.jpg to ./train/
# Moved ./3dprint_full/FC64.txt to ./train/
# Moved ./3dprint_full/FC67.jpg to ./train/
# Moved ./3dprint_full/FC67.txt to ./train/
# Moved ./3dprint_full/FC69.jpg to ./train/
# Moved ./3dprint_full/FC69.txt to ./train/
# Moved ./3dprint_full/FC70.jpg to ./train/
# Moved ./3dprint_full/FC70.txt to ./train/
# Moved ./3dprint_full/FC71.jpg to ./train/
# Moved ./3dprint_full/FC71.txt to ./train/
# Moved ./3dprint_full/FC73.jpg to ./train/
# Moved ./3dprint_full/FC73.txt to ./train/
# Moved ./3dprint_full/FC74.jpg to ./train/
# Moved ./3dprint_full/FC74.txt to ./train/
# Moved ./3dprint_full/FC75.jpg to ./train/
# Moved ./3dprint_full/FC75.txt to ./train/
# Moved ./3dprint_full/FC76.jpg to ./train/
# Moved ./3dprint_full/FC76.txt to ./train/
# Moved ./3dprint_full/FC77.jpg to ./train/
# Moved ./3dprint_full/FC77.txt to ./train/
# Moved ./3dprint_full/FC79.jpg to ./train/
# Moved ./3dprint_full/FC79.txt to ./train/
# Moved ./3dprint_full/FC80.jpg to ./train/
# Moved ./3dprint_full/FC80.txt to ./train/
# Moved ./3dprint_full/FC81.jpg to ./train/
# Moved ./3dprint_full/FC81.txt to ./train/
# Moved ./3dprint_full/FC83.jpg to ./train/
# Moved ./3dprint_full/FC83.txt to ./train/
# Moved ./3dprint_full/FC85.jpg to ./train/
# Moved ./3dprint_full/FC85.txt to ./train/
# Moved ./3dprint_full/FF001.png to ./train/
# Moved ./3dprint_full/FF001.txt to ./train/
# Moved ./3dprint_full/FF002.png to ./train/
# Label file ./3dprint_full/FF002.txt does not exist and was skipped.
# Moved ./3dprint_full/FF005.png to ./train/
# Label file ./3dprint_full/FF005.txt does not exist and was skipped.
# Moved ./3dprint_full/FF006.png to ./train/
# Moved ./3dprint_full/FF006.txt to ./train/
# Moved ./3dprint_full/FF008.png to ./train/
# Moved ./3dprint_full/FF008.txt to ./train/
# Moved ./3dprint_full/FF009.png to ./train/
# Moved ./3dprint_full/FF009.txt to ./train/
# Moved ./3dprint_full/FF010.png to ./train/
# Moved ./3dprint_full/FF010.txt to ./train/
# Moved ./3dprint_full/FF014.png to ./train/
# Moved ./3dprint_full/FF014.txt to ./train/
# Moved ./3dprint_full/FF015.png to ./train/
# Moved ./3dprint_full/FF015.txt to ./train/
# Moved ./3dprint_full/FF016.png to ./train/
# Moved ./3dprint_full/FF016.txt to ./train/
# Moved ./3dprint_full/FF017.png to ./train/
# Moved ./3dprint_full/FF017.txt to ./train/
# Moved ./3dprint_full/FF018.png to ./train/
# Moved ./3dprint_full/FF018.txt to ./train/
# Moved ./3dprint_full/FF019.png to ./train/
# Moved ./3dprint_full/FF019.txt to ./train/
# Moved ./3dprint_full/FF020.png to ./train/
# Moved ./3dprint_full/FF020.txt to ./train/
# Moved ./3dprint_full/FF021.png to ./train/
# Moved ./3dprint_full/FF021.txt to ./train/
# Moved ./3dprint_full/FF022.png to ./train/
# Moved ./3dprint_full/FF022.txt to ./train/
# Moved ./3dprint_full/FF023.png to ./train/
# Moved ./3dprint_full/FF023.txt to ./train/
# Moved ./3dprint_full/FF024.png to ./train/
# Moved ./3dprint_full/FF024.txt to ./train/
# Moved ./3dprint_full/FF025.png to ./train/
# Moved ./3dprint_full/FF025.txt to ./train/
# Moved ./3dprint_full/FF026.png to ./train/
# Moved ./3dprint_full/FF026.txt to ./train/
# Moved ./3dprint_full/FF027.png to ./train/
# Moved ./3dprint_full/FF027.txt to ./train/
# Moved ./3dprint_full/FF028.png to ./train/
# Moved ./3dprint_full/FF028.txt to ./train/
# Moved ./3dprint_full/FF029.png to ./train/
# Moved ./3dprint_full/FF029.txt to ./train/
# Moved ./3dprint_full/FF030.png to ./train/
# Moved ./3dprint_full/FF030.txt to ./train/
# Moved ./3dprint_full/FF031.png to ./train/
# Moved ./3dprint_full/FF031.txt to ./train/
# Moved ./3dprint_full/FF032.png to ./train/
# Moved ./3dprint_full/FF032.txt to ./train/
# Moved ./3dprint_full/FF034.png to ./train/
# Moved ./3dprint_full/FF034.txt to ./train/
# Moved ./3dprint_full/FF035.png to ./train/
# Moved ./3dprint_full/FF035.txt to ./train/
# Moved ./3dprint_full/FF036.png to ./train/
# Moved ./3dprint_full/FF036.txt to ./train/
# Moved ./3dprint_full/FF037.png to ./train/
# Moved ./3dprint_full/FF037.txt to ./train/
# Moved ./3dprint_full/FF038.png to ./train/
# Moved ./3dprint_full/FF038.txt to ./train/
# Moved ./3dprint_full/FF039.png to ./train/
# Moved ./3dprint_full/FF039.txt to ./train/
# Moved ./3dprint_full/FF040.png to ./train/
# Moved ./3dprint_full/FF040.txt to ./train/
# Moved ./3dprint_full/FF041.png to ./train/
# Moved ./3dprint_full/FF041.txt to ./train/
# Moved ./3dprint_full/FF043.png to ./train/
# Moved ./3dprint_full/FF043.txt to ./train/
# Moved ./3dprint_full/FF044.png to ./train/
# Moved ./3dprint_full/FF044.txt to ./train/
# Moved ./3dprint_full/FF045.png to ./train/
# Moved ./3dprint_full/FF045.txt to ./train/
# Moved ./3dprint_full/FF046.png to ./train/
# Moved ./3dprint_full/FF046.txt to ./train/
# Moved ./3dprint_full/FF047.png to ./train/
# Moved ./3dprint_full/FF047.txt to ./train/
# Moved ./3dprint_full/FF048.png to ./train/
# Moved ./3dprint_full/FF048.txt to ./train/
# Moved ./3dprint_full/FF049.png to ./train/
# Moved ./3dprint_full/FF049.txt to ./train/
# Moved ./3dprint_full/FF050.png to ./train/
# Moved ./3dprint_full/FF050.txt to ./train/
# Moved ./3dprint_full/FF051.png to ./train/
# Moved ./3dprint_full/FF051.txt to ./train/
# Moved ./3dprint_full/FF052.png to ./train/
# Moved ./3dprint_full/FF052.txt to ./train/
# Moved ./3dprint_full/FF053.png to ./train/
# Moved ./3dprint_full/FF053.txt to ./train/
# Moved ./3dprint_full/FF055.png to ./train/
# Moved ./3dprint_full/FF055.txt to ./train/
# Moved ./3dprint_full/FF056.png to ./train/
# Moved ./3dprint_full/FF056.txt to ./train/
# Moved ./3dprint_full/FF057.png to ./train/
# Moved ./3dprint_full/FF057.txt to ./train/
# Moved ./3dprint_full/FF058.png to ./train/
# Moved ./3dprint_full/FF058.txt to ./train/
# Moved ./3dprint_full/FF059.png to ./train/
# Moved ./3dprint_full/FF059.txt to ./train/
# Moved ./3dprint_full/FF060.png to ./train/
# Moved ./3dprint_full/FF060.txt to ./train/
# Moved ./3dprint_full/FF061.png to ./train/
# Moved ./3dprint_full/FF061.txt to ./train/
# Moved ./3dprint_full/FF062.png to ./train/
# Moved ./3dprint_full/FF062.txt to ./train/
# Moved ./3dprint_full/FF063.png to ./train/
# Moved ./3dprint_full/FF063.txt to ./train/
# Moved ./3dprint_full/FF064.png to ./train/
# Moved ./3dprint_full/FF064.txt to ./train/
# Moved ./3dprint_full/FF065.png to ./train/
# Moved ./3dprint_full/FF065.txt to ./train/
# Moved ./3dprint_full/FF066.png to ./train/
# Moved ./3dprint_full/FF066.txt to ./train/
# Moved ./3dprint_full/FF067.png to ./train/
# Moved ./3dprint_full/FF067.txt to ./train/
# Moved ./3dprint_full/FF068.png to ./train/
# Moved ./3dprint_full/FF068.txt to ./train/
# Moved ./3dprint_full/FF069.png to ./train/
# Moved ./3dprint_full/FF069.txt to ./train/
# Moved ./3dprint_full/FF070.png to ./train/
# Moved ./3dprint_full/FF070.txt to ./train/
# Moved ./3dprint_full/FF071.png to ./train/
# Moved ./3dprint_full/FF071.txt to ./train/
# Moved ./3dprint_full/FF072.png to ./train/
# Moved ./3dprint_full/FF072.txt to ./train/
# Moved ./3dprint_full/FF073.png to ./train/
# Moved ./3dprint_full/FF073.txt to ./train/
# Moved ./3dprint_full/FF074.png to ./train/
# Moved ./3dprint_full/FF074.txt to ./train/
# Moved ./3dprint_full/FF075.png to ./train/
# Moved ./3dprint_full/FF075.txt to ./train/
# Moved ./3dprint_full/FF077.png to ./train/
# Moved ./3dprint_full/FF077.txt to ./train/
# Moved ./3dprint_full/FF079.png to ./train/
# Moved ./3dprint_full/FF079.txt to ./train/
# Moved ./3dprint_full/FF080.png to ./train/
# Moved ./3dprint_full/FF080.txt to ./train/
# Moved ./3dprint_full/FF081.png to ./train/
# Moved ./3dprint_full/FF081.txt to ./train/
# Moved ./3dprint_full/FF082.png to ./train/
# Label file ./3dprint_full/FF082.txt does not exist and was skipped.
# Moved ./3dprint_full/FF083.png to ./train/
# Moved ./3dprint_full/FF083.txt to ./train/
# Moved ./3dprint_full/FF084.png to ./train/
# Moved ./3dprint_full/FF084.txt to ./train/
# Moved ./3dprint_full/FF085.png to ./train/
# Moved ./3dprint_full/FF085.txt to ./train/
# Moved ./3dprint_full/FF086.png to ./train/
# Moved ./3dprint_full/FF086.txt to ./train/
# Moved ./3dprint_full/FF087.png to ./train/
# Moved ./3dprint_full/FF087.txt to ./train/
# Moved ./3dprint_full/FF089.png to ./train/
# Moved ./3dprint_full/FF089.txt to ./train/
# Moved ./3dprint_full/FF090.png to ./train/
# Moved ./3dprint_full/FF090.txt to ./train/
# Moved ./3dprint_full/FF091.png to ./train/
# Moved ./3dprint_full/FF091.txt to ./train/
# Moved ./3dprint_full/FF092.png to ./train/
# Moved ./3dprint_full/FF092.txt to ./train/
# Moved ./3dprint_full/FF093.png to ./train/
# Moved ./3dprint_full/FF093.txt to ./train/
# Moved ./3dprint_full/FF094.png to ./train/
# Moved ./3dprint_full/FF094.txt to ./train/
# Moved ./3dprint_full/FF095.png to ./train/
# Moved ./3dprint_full/FF095.txt to ./train/
# Moved ./3dprint_full/FF097.png to ./train/
# ...
# Moved ./3dprint_full/PG032.png to ./train/
# Moved ./3dprint_full/PG032.txt to ./train/
# Moved ./3dprint_full/PG033.png to ./train/
# Moved ./3dprint_full/PG033.txt to ./train/
# Moved ./3dprint_full/PG034.png to ./train/
# Moved ./3dprint_full/PG034.txt to ./train/
# Moved ./3dprint_full/PG035.png to ./train/
# Moved ./3dprint_full/PG035.txt to ./train/
# Moved ./3dprint_full/PG038.png to ./train/
# Moved ./3dprint_full/PG038.txt to ./train/
# Moved ./3dprint_full/PG039.png to ./train/
# Moved ./3dprint_full/PG039.txt to ./train/
# Moved ./3dprint_full/PG040.png to ./train/
# Moved ./3dprint_full/PG040.txt to ./train/
# Moved ./3dprint_full/PG041.png to ./train/
# Moved ./3dprint_full/PG041.txt to ./train/
# Moved ./3dprint_full/PG042.png to ./train/
# Moved ./3dprint_full/PG042.txt to ./train/
# Moved ./3dprint_full/PG043.png to ./train/
# Moved ./3dprint_full/PG043.txt to ./train/
# Moved ./3dprint_full/PG044.png to ./train/
# Moved ./3dprint_full/PG044.txt to ./train/
# Moved ./3dprint_full/BA001.png to ./val/
# Label file ./3dprint_full/BA001.txt does not exist and was skipped.
# Moved ./3dprint_full/BA019.png to ./val/
# Label file ./3dprint_full/BA019.txt does not exist and was skipped.
# Moved ./3dprint_full/BA023.png to ./val/
# Label file ./3dprint_full/BA023.txt does not exist and was skipped.
# Moved ./3dprint_full/BA032.png to ./val/
# Label file ./3dprint_full/BA032.txt does not exist and was skipped.
# Moved ./3dprint_full/BA034.png to ./val/
# Label file ./3dprint_full/BA034.txt does not exist and was skipped.
# Moved ./3dprint_full/BA039.png to ./val/
# Label file ./3dprint_full/BA039.txt does not exist and was skipped.
# Moved ./3dprint_full/BA043.png to ./val/
# Label file ./3dprint_full/BA043.txt does not exist and was skipped.
# Moved ./3dprint_full/BA046.png to ./val/
# Label file ./3dprint_full/BA046.txt does not exist and was skipped.
# Moved ./3dprint_full/BA051.png to ./val/
# Label file ./3dprint_full/BA051.txt does not exist and was skipped.
# Moved ./3dprint_full/BA061.png to ./val/
# Label file ./3dprint_full/BA061.txt does not exist and was skipped.
# Moved ./3dprint_full/BA078.png to ./val/
# Label file ./3dprint_full/BA078.txt does not exist and was skipped.
# Moved ./3dprint_full/BA080.png to ./val/
# Label file ./3dprint_full/BA080.txt does not exist and was skipped.
# Moved ./3dprint_full/BA081.png to ./val/
# Label file ./3dprint_full/BA081.txt does not exist and was skipped.
# Moved ./3dprint_full/BA087.png to ./val/
# Label file ./3dprint_full/BA087.txt does not exist and was skipped.
# Moved ./3dprint_full/BA088.png to ./val/
# Label file ./3dprint_full/BA088.txt does not exist and was skipped.
# Moved ./3dprint_full/BA089.png to ./val/
# Label file ./3dprint_full/BA089.txt does not exist and was skipped.
# Moved ./3dprint_full/BA102.png to ./val/
# Label file ./3dprint_full/BA102.txt does not exist and was skipped.
# Moved ./3dprint_full/BA109.png to ./val/
# Label file ./3dprint_full/BA109.txt does not exist and was skipped.
# Moved ./3dprint_full/BA131.png to ./val/
# Label file ./3dprint_full/BA131.txt does not exist and was skipped.
# Moved ./3dprint_full/BA148.png to ./val/
# Label file ./3dprint_full/BA148.txt does not exist and was skipped.
# Moved ./3dprint_full/BA155.png to ./val/
# Label file ./3dprint_full/BA155.txt does not exist and was skipped.
# Moved ./3dprint_full/BA167.png to ./val/
# Label file ./3dprint_full/BA167.txt does not exist and was skipped.
# Moved ./3dprint_full/BG104.jpg to ./val/
# Label file ./3dprint_full/BG104.txt does not exist and was skipped.
# Moved ./3dprint_full/BG118.jpg to ./val/
# Label file ./3dprint_full/BG118.txt does not exist and was skipped.
# Moved ./3dprint_full/BG121.jpg to ./val/
# Label file ./3dprint_full/BG121.txt does not exist and was skipped.
# Moved ./3dprint_full/BG122.jpg to ./val/
# Label file ./3dprint_full/BG122.txt does not exist and was skipped.
# Moved ./3dprint_full/BG123.jpg to ./val/
# Label file ./3dprint_full/BG123.txt does not exist and was skipped.
# Moved ./3dprint_full/BG135.jpg to ./val/
# Label file ./3dprint_full/BG135.txt does not exist and was skipped.
# Moved ./3dprint_full/BG15.jpg to ./val/
# Label file ./3dprint_full/BG15.txt does not exist and was skipped.
# Moved ./3dprint_full/BG19.jpg to ./val/
# Label file ./3dprint_full/BG19.txt does not exist and was skipped.
# Moved ./3dprint_full/BG25.jpg to ./val/
# Label file ./3dprint_full/BG25.txt does not exist and was skipped.
# Moved ./3dprint_full/BG30.jpg to ./val/
# Label file ./3dprint_full/BG30.txt does not exist and was skipped.
# Moved ./3dprint_full/BG76.jpg to ./val/
# Label file ./3dprint_full/BG76.txt does not exist and was skipped.
# Moved ./3dprint_full/BG84.jpg to ./val/
# Label file ./3dprint_full/BG84.txt does not exist and was skipped.
# Moved ./3dprint_full/DP010.png to ./val/
# Moved ./3dprint_full/DP010.txt to ./val/
# Moved ./3dprint_full/DP031.png to ./val/
# Moved ./3dprint_full/DP031.txt to ./val/
# Moved ./3dprint_full/DP043.png to ./val/
# Moved ./3dprint_full/DP043.txt to ./val/
# Moved ./3dprint_full/DP044.png to ./val/
# Moved ./3dprint_full/DP044.txt to ./val/
# Moved ./3dprint_full/DP049.png to ./val/
# Moved ./3dprint_full/DP049.txt to ./val/
# Moved ./3dprint_full/DP053.png to ./val/
# Moved ./3dprint_full/DP053.txt to ./val/
# Moved ./3dprint_full/DP056.png to ./val/
# Moved ./3dprint_full/DP056.txt to ./val/
# Moved ./3dprint_full/DP061.png to ./val/
# Moved ./3dprint_full/DP061.txt to ./val/
# Moved ./3dprint_full/DP072.png to ./val/
# Moved ./3dprint_full/DP072.txt to ./val/
# Moved ./3dprint_full/FA08.jpg to ./val/
# Moved ./3dprint_full/FA08.txt to ./val/
# Moved ./3dprint_full/FA13.jpg to ./val/
# Moved ./3dprint_full/FA13.txt to ./val/
# Moved ./3dprint_full/FA21.jpg to ./val/
# Moved ./3dprint_full/FA21.txt to ./val/
# Moved ./3dprint_full/FA25.jpg to ./val/
# Moved ./3dprint_full/FA25.txt to ./val/
# Moved ./3dprint_full/FA30.jpg to ./val/
# Moved ./3dprint_full/FA30.txt to ./val/
# Moved ./3dprint_full/FB13.jpg to ./val/
# Moved ./3dprint_full/FB13.txt to ./val/
# Moved ./3dprint_full/FC03.jpg to ./val/
# Moved ./3dprint_full/FC03.txt to ./val/
# Moved ./3dprint_full/FC16.jpg to ./val/
# Moved ./3dprint_full/FC16.txt to ./val/
# Moved ./3dprint_full/FC18.jpg to ./val/
# Moved ./3dprint_full/FC18.txt to ./val/
# Moved ./3dprint_full/FC37.jpg to ./val/
# Moved ./3dprint_full/FC37.txt to ./val/
# Moved ./3dprint_full/FC38.jpg to ./val/
# Moved ./3dprint_full/FC38.txt to ./val/
# Moved ./3dprint_full/FC66.jpg to ./val/
# Moved ./3dprint_full/FC66.txt to ./val/
# Moved ./3dprint_full/FC68.jpg to ./val/
# Moved ./3dprint_full/FC68.txt to ./val/
# Moved ./3dprint_full/FC78.jpg to ./val/
# Moved ./3dprint_full/FC78.txt to ./val/
# Moved ./3dprint_full/FF011.png to ./val/
# Moved ./3dprint_full/FF011.txt to ./val/
# Moved ./3dprint_full/FF013.png to ./val/
# Moved ./3dprint_full/FF013.txt to ./val/
# Moved ./3dprint_full/FF078.png to ./val/
# Moved ./3dprint_full/FF078.txt to ./val/
# Moved ./3dprint_full/FF132.png to ./val/
# Moved ./3dprint_full/FF132.txt to ./val/
# Moved ./3dprint_full/FF136.png to ./val/
# Moved ./3dprint_full/FF136.txt to ./val/
# Moved ./3dprint_full/FF144.png to ./val/
# Moved ./3dprint_full/FF144.txt to ./val/
# Moved ./3dprint_full/FF158.png to ./val/
# Moved ./3dprint_full/FF158.txt to ./val/
# Moved ./3dprint_full/FF168.png to ./val/
# Moved ./3dprint_full/FF168.txt to ./val/
# Moved ./3dprint_full/FF187.png to ./val/
# Moved ./3dprint_full/FF187.txt to ./val/
# Moved ./3dprint_full/FF214.png to ./val/
# Moved ./3dprint_full/FF214.txt to ./val/
# Moved ./3dprint_full/FF229.png to ./val/
# Moved ./3dprint_full/FF229.txt to ./val/
# Moved ./3dprint_full/FF239.png to ./val/
# Moved ./3dprint_full/FF239.txt to ./val/
# Moved ./3dprint_full/FF252.png to ./val/
# Moved ./3dprint_full/FF252.txt to ./val/
# Moved ./3dprint_full/PG002.png to ./val/
# Moved ./3dprint_full/PG002.txt to ./val/
# Moved ./3dprint_full/PG026.png to ./val/
# Moved ./3dprint_full/PG026.txt to ./val/
# Moved ./3dprint_full/PG036.png to ./val/
# Moved ./3dprint_full/PG036.txt to ./val/
# Moved ./3dprint_full/PG045.png to ./val/
# Moved ./3dprint_full/PG045.txt to ./val/
# Moved ./3dprint_full/BA011.png to ./test/
# Label file ./3dprint_full/BA011.txt does not exist and was skipped.
# Moved ./3dprint_full/BA017.png to ./test/
# Label file ./3dprint_full/BA017.txt does not exist and was skipped.
# Moved ./3dprint_full/BA018.png to ./test/
# Label file ./3dprint_full/BA018.txt does not exist and was skipped.
# Moved ./3dprint_full/BA020.png to ./test/
# Label file ./3dprint_full/BA020.txt does not exist and was skipped.
# Moved ./3dprint_full/BA029.png to ./test/
# Label file ./3dprint_full/BA029.txt does not exist and was skipped.
# Moved ./3dprint_full/BA030.png to ./test/
# Label file ./3dprint_full/BA030.txt does not exist and was skipped.
# Moved ./3dprint_full/BA050.png to ./test/
# Label file ./3dprint_full/BA050.txt does not exist and was skipped.
# Moved ./3dprint_full/BA056.png to ./test/
# Label file ./3dprint_full/BA056.txt does not exist and was skipped.
# Moved ./3dprint_full/BA063.png to ./test/
# Label file ./3dprint_full/BA063.txt does not exist and was skipped.
# Moved ./3dprint_full/BA079.png to ./test/
# Label file ./3dprint_full/BA079.txt does not exist and was skipped.
# Moved ./3dprint_full/BA082.png to ./test/
# Label file ./3dprint_full/BA082.txt does not exist and was skipped.
# Moved ./3dprint_full/BA091.png to ./test/
# Label file ./3dprint_full/BA091.txt does not exist and was skipped.
# Moved ./3dprint_full/BA095.png to ./test/
# Label file ./3dprint_full/BA095.txt does not exist and was skipped.
# Moved ./3dprint_full/BA096.png to ./test/
# Label file ./3dprint_full/BA096.txt does not exist and was skipped.
# Moved ./3dprint_full/BA115.png to ./test/
# Label file ./3dprint_full/BA115.txt does not exist and was skipped.
# Moved ./3dprint_full/BA124.png to ./test/
# Label file ./3dprint_full/BA124.txt does not exist and was skipped.
# Moved ./3dprint_full/BA127.png to ./test/
# Label file ./3dprint_full/BA127.txt does not exist and was skipped.
# Moved ./3dprint_full/BA132.png to ./test/
# Label file ./3dprint_full/BA132.txt does not exist and was skipped.
# Moved ./3dprint_full/BA144.png to ./test/
# Label file ./3dprint_full/BA144.txt does not exist and was skipped.
# Moved ./3dprint_full/BA149.png to ./test/
# Label file ./3dprint_full/BA149.txt does not exist and was skipped.
# Moved ./3dprint_full/BA152.png to ./test/
# Label file ./3dprint_full/BA152.txt does not exist and was skipped.
# Moved ./3dprint_full/BA176.png to ./test/
# Label file ./3dprint_full/BA176.txt does not exist and was skipped.
# Moved ./3dprint_full/BG02.jpg to ./test/
# Label file ./3dprint_full/BG02.txt does not exist and was skipped.
# Moved ./3dprint_full/BG125.jpg to ./test/
# Label file ./3dprint_full/BG125.txt does not exist and was skipped.
# Moved ./3dprint_full/BG129.jpg to ./test/
# Label file ./3dprint_full/BG129.txt does not exist and was skipped.
# Moved ./3dprint_full/BG17.jpg to ./test/
# Label file ./3dprint_full/BG17.txt does not exist and was skipped.
# Moved ./3dprint_full/BG36.jpg to ./test/
# Label file ./3dprint_full/BG36.txt does not exist and was skipped.
# Moved ./3dprint_full/BG37.jpg to ./test/
# Label file ./3dprint_full/BG37.txt does not exist and was skipped.
# Moved ./3dprint_full/BG38.jpg to ./test/
# Label file ./3dprint_full/BG38.txt does not exist and was skipped.
# Moved ./3dprint_full/BG44.jpg to ./test/
# Label file ./3dprint_full/BG44.txt does not exist and was skipped.
# Moved ./3dprint_full/BG59.jpg to ./test/
# Label file ./3dprint_full/BG59.txt does not exist and was skipped.
# Moved ./3dprint_full/BG74.jpg to ./test/
# Label file ./3dprint_full/BG74.txt does not exist and was skipped.
# Moved ./3dprint_full/BG77.jpg to ./test/
# Label file ./3dprint_full/BG77.txt does not exist and was skipped.
# Moved ./3dprint_full/BG85.jpg to ./test/
# Label file ./3dprint_full/BG85.txt does not exist and was skipped.
# Moved ./3dprint_full/BG88.jpg to ./test/
# Label file ./3dprint_full/BG88.txt does not exist and was skipped.
# Moved ./3dprint_full/DP004.png to ./test/
# Moved ./3dprint_full/DP004.txt to ./test/
# Moved ./3dprint_full/DP012.png to ./test/
# Moved ./3dprint_full/DP012.txt to ./test/
# Moved ./3dprint_full/DP019.png to ./test/
# Moved ./3dprint_full/DP019.txt to ./test/
# Moved ./3dprint_full/DP026.png to ./test/
# Moved ./3dprint_full/DP026.txt to ./test/
# Moved ./3dprint_full/DP027.png to ./test/
# Moved ./3dprint_full/DP027.txt to ./test/
# Moved ./3dprint_full/DP033.png to ./test/
# Moved ./3dprint_full/DP033.txt to ./test/
# Moved ./3dprint_full/DP042.png to ./test/
# Moved ./3dprint_full/DP042.txt to ./test/
# Moved ./3dprint_full/DP066.png to ./test/
# Moved ./3dprint_full/DP066.txt to ./test/
# Moved ./3dprint_full/DP068.png to ./test/
# Moved ./3dprint_full/DP068.txt to ./test/
# Moved ./3dprint_full/DP074.png to ./test/
# Moved ./3dprint_full/DP074.txt to ./test/
# Moved ./3dprint_full/DP076.png to ./test/
# Moved ./3dprint_full/DP076.txt to ./test/
# Moved ./3dprint_full/FA22.jpg to ./test/
# Moved ./3dprint_full/FA22.txt to ./test/
# Moved ./3dprint_full/FB17.jpg to ./test/
# Moved ./3dprint_full/FB17.txt to ./test/
# Moved ./3dprint_full/FC13.jpg to ./test/
# Moved ./3dprint_full/FC13.txt to ./test/
# Moved ./3dprint_full/FC15.jpg to ./test/
# Moved ./3dprint_full/FC15.txt to ./test/
# Moved ./3dprint_full/FC29.jpg to ./test/
# Moved ./3dprint_full/FC29.txt to ./test/
# Moved ./3dprint_full/FC31.jpg to ./test/
# Moved ./3dprint_full/FC31.txt to ./test/
# Moved ./3dprint_full/FC32.jpg to ./test/
# Moved ./3dprint_full/FC32.txt to ./test/
# Moved ./3dprint_full/FC46.jpg to ./test/
# Moved ./3dprint_full/FC46.txt to ./test/
# Moved ./3dprint_full/FC47.jpg to ./test/
# Moved ./3dprint_full/FC47.txt to ./test/
# Moved ./3dprint_full/FC56.jpg to ./test/
# Moved ./3dprint_full/FC56.txt to ./test/
# Moved ./3dprint_full/FC57.jpg to ./test/
# Moved ./3dprint_full/FC57.txt to ./test/
# Moved ./3dprint_full/FC65.jpg to ./test/
# Moved ./3dprint_full/FC65.txt to ./test/
# Moved ./3dprint_full/FC72.jpg to ./test/
# Moved ./3dprint_full/FC72.txt to ./test/
# Moved ./3dprint_full/FC82.jpg to ./test/
# Moved ./3dprint_full/FC82.txt to ./test/
# Moved ./3dprint_full/FC84.jpg to ./test/
# Moved ./3dprint_full/FC84.txt to ./test/
# Moved ./3dprint_full/FF003.png to ./test/
# Label file ./3dprint_full/FF003.txt does not exist and was skipped.
# Moved ./3dprint_full/FF004.png to ./test/
# Label file ./3dprint_full/FF004.txt does not exist and was skipped.
# Moved ./3dprint_full/FF007.png to ./test/
# Moved ./3dprint_full/FF007.txt to ./test/
# Moved ./3dprint_full/FF012.png to ./test/
# Moved ./3dprint_full/FF012.txt to ./test/
# Moved ./3dprint_full/FF033.png to ./test/
# Moved ./3dprint_full/FF033.txt to ./test/
# Moved ./3dprint_full/FF042.png to ./test/
# Moved ./3dprint_full/FF042.txt to ./test/
# Moved ./3dprint_full/FF054.png to ./test/
# Moved ./3dprint_full/FF054.txt to ./test/
# Moved ./3dprint_full/FF076.png to ./test/
# Moved ./3dprint_full/FF076.txt to ./test/
# Moved ./3dprint_full/FF088.png to ./test/
# Moved ./3dprint_full/FF088.txt to ./test/
# Moved ./3dprint_full/FF096.png to ./test/
# Moved ./3dprint_full/FF096.txt to ./test/
# Moved ./3dprint_full/FF143.png to ./test/
# Label file ./3dprint_full/FF143.txt does not exist and was skipped.
# Moved ./3dprint_full/FF164.png to ./test/
# Moved ./3dprint_full/FF164.txt to ./test/
# Moved ./3dprint_full/FF172.png to ./test/
# Moved ./3dprint_full/FF172.txt to ./test/
# Moved ./3dprint_full/FF192.png to ./test/
# Moved ./3dprint_full/FF192.txt to ./test/
# Moved ./3dprint_full/FF193.png to ./test/
# Moved ./3dprint_full/FF193.txt to ./test/
# Moved ./3dprint_full/FF194.png to ./test/
# Label file ./3dprint_full/FF194.txt does not exist and was skipped.
# Moved ./3dprint_full/FF195.png to ./test/
# Moved ./3dprint_full/FF195.txt to ./test/
# Moved ./3dprint_full/FF208.png to ./test/
# Moved ./3dprint_full/FF208.txt to ./test/
# Moved ./3dprint_full/FF210.png to ./test/
# Moved ./3dprint_full/FF210.txt to ./test/
# Moved ./3dprint_full/FF234.png to ./test/
# Moved ./3dprint_full/FF234.txt to ./test/
# Moved ./3dprint_full/FF240.png to ./test/
# Moved ./3dprint_full/FF240.txt to ./test/
# Moved ./3dprint_full/FF247.png to ./test/
# Moved ./3dprint_full/FF247.txt to ./test/
# Moved ./3dprint_full/PG003.png to ./test/
# Moved ./3dprint_full/PG003.txt to ./test/
# Dataset files and labels have been moved to respective directories.
